# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine("mysql+pymysql://root:teamlab2016@ortega@192.9.64.15/trademarks")

# %%
df = pd.read_sql("select * from Images limit 10", con=engine)

# %%
df
# Out:
#    TrademarkKey            viennaCode appReferenceNumber applicationNumber  \
# 0             1  050519 050520 050521      4020107009967
# 1             2                            4020107001276
# 2             3                            4020177005758
# 3             4                            4020187016370
# 4             5                            4020067002628
# 5             6                            4020067004760
# 6             7                                              4019500000040
# 7             8                                              4019500000034
# 8             9                                              4019500000037
# 9            10                                              4019500000039
#
#                                          SourceImage TargetImage  \
# 0  iVBORw0KGgoAAAANSUhEUgAAAGQAAABkCAAAAABVicqIAA...
# 1  iVBORw0KGgoAAAANSUhEUgAAAGQAAABkCAAAAABVicqIAA...
# 2  iVBORw0KGgoAAAANSUhEUgAAAGQAAABkCAAAAABVicqIAA...
# ...
